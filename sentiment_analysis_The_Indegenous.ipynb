# %%
pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 7.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (2022.12.7)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import requests
import json
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# Fetching news from newsapi using my api key
r = requests.get("https://newsapi.org/v2/top-headlines?country=in&apiKey=6055d45c88d6425ea9b476a9310e3915")

data = json.loads(r.content)

negative = []
neutral = []
positive = []

# Calculating the Sentiment Scores
for i in range(len(data["articles"])):

    title = data['articles'][i]['title']
    description = data['articles'][i]['description']

    if(title == None or description == None):
        continue
    
    title_analyzed = analyzer.polarity_scores(title)
    description_analyzed = analyzer.polarity_scores(description)
    
    negative.append(((title_analyzed["neg"]) + (description_analyzed["neg"])) / 2)
    neutral.append(((title_analyzed["neu"]) + (description_analyzed["neu"])) / 2)
    positive.append(((title_analyzed["pos"]) + (description_analyzed["pos"])) / 2)


# Printing
for i in range(len(negative)):
    
    title = data['articles'][i]['title']

    print("News",i + 1,":")
    print("Topic :",title)
    print("Negative Score :",negative[i])
    print("Neutral Score :",neutral[i])
    print("Positive Score :",positive[i])
    print("\n\n")
# Out:
# News 1 :
# Topic : "Didn't Intend To Insult Bihar": Minister Piyush Goyal Withdraws Remark - NDTV
# Negative Score : 0.0965
# Neutral Score : 0.785
# Positive Score : 0.11850000000000001
#
#
#
# News 2 :
# Topic : WhatsApp message on Covid XBB variant going viral, health ministry says it is fake - India Today
# Negative Score : 0.21850000000000003
# Neutral Score : 0.7815
# Positive Score : 0.0
#
#
#
# News 3 :
# Topic : Shanghai hospital warns of 'tragic battle' as COVID spreads - Reuters
# Negative Score : 0.3255
# Neutral Score : 0.6745
# Positive Score : 0.0
#
#
#
# News 4 :
# Topic : "Government Released Covid Virus" To Stop Rahul Gandhi Yatra: Team Uddhav - NDTV
# Negative Score : 0.0985
# Neutral Score : 0.9015
# Positive Score : 0.0
#
#
#
# News 5 :
# Topic : Why China Has Brought This Huge Covid Surge Upon Itself - NDTV
# Negative Score : 0.073
# Neutral Score : 0.8305
# Positive Score : 0.0965
#
#
#
# News 6 :
# Topic : Study finds how long Covid causes smell loss for months, even years - Economic Times
# Negative Score : 0.144
# Neutral Score : 0.821
# Positive Score : 0.035
#
#
#
# News 7 :
# Topic : NASA finally bids goodbye to InSight Mars lander -  Argus News
# Negative Score : 0.0
# Neutral Score : 1.0
# Positive Score : 0.0
#
#
#
# News 8 :
# Topic : OnePlus Buds Pro 2 design, colour option, and features confirmed - The Indian Express
# Negative Score : 0.0
# Neutral Score : 1.0
# Positive Score : 0.0
#
#
#
# News 9 :
# Topic : Perseverance rover drops first sample on Mars depot to be brought to Earth - India Today
# Negative Score : 0.0
# Neutral Score : 1.0
# Positive Score : 0.0
#
#
#
# News 10 :
# Topic : India vs Bangladesh 2nd Test, Day 1 Live Updates: Umesh Yadav Gets Shakib Al Hasan, Bangladesh 3 Down - NDTV Sports
# Negative Score : 0.0
# Neutral Score : 1.0
# Positive Score : 0.0
#
#
#
# News 11 :
# Topic : Pathaan song Jhoome Jo Pathaan: Shah Rukh Khan, Deepika dance into your hearts - Hindustan Times
# Negative Score : 0.0
# Neutral Score : 0.8275
# Positive Score : 0.1725
#
#
#
# News 12 :
# Topic : Bird Flu Outbreak In Europe: 2500 Outbreaks In 37 Countries This Year | TheHealthSite.com - TheHealthSite
# Negative Score : 0.1175
# Neutral Score : 0.6525
# Positive Score : 0.22999999999999998
#
#
#
# News 13 :
# Topic : Amitabh Bachchan On Abhishek's Filmfare OTT Awards: "You Were Derided, Ridiculed..." - NDTV Movies
# Negative Score : 0.046
# Neutral Score : 0.756
# Positive Score : 0.1985
#
#
#
# News 14 :
# Topic : Google Links More Of CEO Sundar Pichai's Pay To Performance - NDTV Profit
# Negative Score : 0.20950000000000002
# Neutral Score : 0.7905
# Positive Score : 0.0
#
#
#
# News 15 :
# Topic : 500-foot MAMMOTH asteroid heading for Earth today, says NASA; Scary rock flying at 36969 kmph - HT Tech
# Negative Score : 0.20450000000000002
# Neutral Score : 0.7384999999999999
# Positive Score : 0.057
#
#
#
# News 16 :
# Topic : Will Covid Comeback Haunt India Again? As China Battles Surge, Experts Clear the Air | Explained - News18
# Negative Score : 0.0
# Neutral Score : 1.0
# Positive Score : 0.0
#
#
#
# News 17 :
# Topic : IPL 2023 auction - Who is the biggest buy at an IPL mini auction? Which team had the smallest remaining purse? - ESPNcricinfo
# Negative Score : 0.123
# Neutral Score : 0.5245
# Positive Score : 0.35250000000000004
#
#
#
# News 18 :
# Topic : Garena Free Fire MAX Redeem Codes for December 22: Win awesome outfits and weapons - HT Tech
# Negative Score : 0.0
# Neutral Score : 1.0
# Positive Score : 0.0
#
#
#
# News 19 :
# Topic : Najam Sethi set to replace Ramiz Raja as PCB chairman | Cricbuzz.com - Cricbuzz - Cricbuzz
# Negative Score : 0.0
# Neutral Score : 0.917
# Positive Score : 0.083
